# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder

import lightgbm as lgb

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train_test = pd.concat([train, test], axis=0)

# %%
train.drop(columns=['Name', 'Cabin', 'Ticket'], inplace=True)
test.drop(columns=['Name', 'Cabin','Ticket'], inplace=True)

# %%
#quickly fill na values
def fill_na_benchmark(df_train, df_test):
    #fill missing values with most frequent values for categorical
    numeric_cols = df_train.select_dtypes(exclude=['object']).drop(columns=['Survived']).columns
    cat_cols = df_train.select_dtypes(include=['object']).columns
    print(cat_cols)
    print(numeric_cols)
    imputer = SimpleImputer(strategy='most_frequent')
    imputer.fit(df_train[cat_cols])
    df_train[cat_cols] = imputer.transform(df_train[cat_cols])
    df_test[cat_cols] = imputer.transform(df_test[cat_cols])
    
    # ordinal encoder, transform categorical labels
    ode = OrdinalEncoder()
    ode.fit(df_train[cat_cols])
    df_train[cat_cols] = ode.transform(df_train[cat_cols])
    df_test[cat_cols] = ode.transform(df_test[cat_cols])
    
    ## fill missing values with mean for numeric
    to_fill = {}
    for col in numeric_cols:
        to_fill[col] = df_train[col].mean()    
    df_train.fillna(value=to_fill, inplace=True)
    df_test.fillna(value=to_fill, inplace=True)
    
    return df_train, df_test, to_fill

# %%
train, test, to_fill = fill_na_benchmark(train, test)
# Out:
# Index(['Sex', 'Embarked'], dtype='object')
# Index(['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %% [markdown]
# ### Lightgbm Benchmark

# %%
# Prapre train and test

X_train, y_train = train.drop(columns=['Survived']), train['Survived']

params = {'boosting_type': 'gbdt', 'objective': 'binary', 'n_estimators':200,
              'num_leaves': 100, 'learning_rate': 0.01, 'max_bin': 512, 
              'subsample_for_bin': 200, 'subsample': 1, 'subsample_freq': 1,
              'colsample_bytree': 0.8, 'reg_alpha': 5, 'reg_lambda': 10, 'metric': 'binary_logloss'}


lgbm = lgb.LGBMClassifier(**params)
lgbm.fit(X_train, y_train, categorical_feature=['Sex', 'Embarked'], eval_set=[(X_train, y_train)], early_stopping_rounds=20)
y_pred = lgbm.predict(test)
# Out:
# [1]	training's binary_logloss: 0.662757
# [2]	training's binary_logloss: 0.659737
# [3]	training's binary_logloss: 0.656931
# [4]	training's binary_logloss: 0.653793
# [5]	training's binary_logloss: 0.65068
# [6]	training's binary_logloss: 0.647854
# [7]	training's binary_logloss: 0.64484
# [8]	training's binary_logloss: 0.643536
# [9]	training's binary_logloss: 0.640815
# [10]	training's binary_logloss: 0.637913
# [11]	training's binary_logloss: 0.63506
# [12]	training's binary_logloss: 0.632468
# [13]	training's binary_logloss: 0.629708
# [14]	training's binary_logloss: 0.627161
# [15]	training's binary_logloss: 0.624515
# [16]	training's binary_logloss: 0.622218
# [17]	training's binary_logloss: 0.619625
# [18]	training's binary_logloss: 0.617075
# [19]	training's binary_logloss: 0.614885
# [20]	training's binary_logloss: 0.612406
# [21]	training's binary_logloss: 0.611348
# [22]	training's binary_logloss: 0.609143
# [23]	training's binary_logloss: 0.60675
# [24]	training's binary_logloss: 0.604395
# [25]	training's binary_logloss: 0.602076
# [26]	training's binary_logloss: 0.599794
# [27]	training's binary_logloss: 0.598814
# [28]	training's binary_logloss: 0.596571
# [29]	training's binary_logloss: 0.594486
# [30]	training's binary_logloss: 0.5935
# [31]	training's binary_logloss: 0.591493
# [32]	training's binary_logloss: 0.589358
# [33]	training's binary_logloss: 0.587412
# [34]	training's binary_logloss: 0.585339
# [35]	training's binary_logloss: 0.584432
# [36]	training's binary_logloss: 0.582403
# [37]	training's binary_logloss: 0.581616
# [38]	training's binary_logloss: 0.580635
# [39]	training's binary_logloss: 0.579796
# [40]	training's binary_logloss: 0.577836
# [41]	training's binary_logloss: 0.577003
# [42]	training's binary_logloss: 0.575075
# [43]	training's binary_logloss: 0.574252
# [44]	training's binary_logloss: 0.572475
# [45]	training's binary_logloss: 0.571703
# [46]	training's binary_logloss: 0.569867
# [47]	training's binary_logloss: 0.568152
# [48]	training's binary_logloss: 0.566461
# [49]	training's binary_logloss: 0.565608
# [50]	training's binary_logloss: 0.563835
# [51]	training's binary_logloss: 0.562201
# [52]	training's binary_logloss: 0.560592
# [53]	training's binary_logloss: 0.559028
# [54]	training's binary_logloss: 0.558226
# [55]	training's binary_logloss: 0.556564
# [56]	training's binary_logloss: 0.555049
# [57]	training's binary_logloss: 0.553537
# [58]	training's binary_logloss: 0.552047
# [59]	training's binary_logloss: 0.551399
# [60]	training's binary_logloss: 0.549938
# [61]	training's binary_logloss: 0.548393
# [62]	training's binary_logloss: 0.547664
# [63]	training's binary_logloss: 0.546271
# [64]	training's binary_logloss: 0.544761
# [65]	training's binary_logloss: 0.544139
# [66]	training's binary_logloss: 0.542677
# [67]	training's binary_logloss: 0.541305
# [68]	training's binary_logloss: 0.539868
# [69]	training's binary_logloss: 0.538558
# [70]	training's binary_logloss: 0.53804
# [71]	training's binary_logloss: 0.537427
# [72]	training's binary_logloss: 0.536877
# [73]	training's binary_logloss: 0.535572
# [74]	training's binary_logloss: 0.534334
# [75]	training's binary_logloss: 0.533748
# [76]	training's binary_logloss: 0.532533
# [77]	training's binary_logloss: 0.531283
# [78]	training's binary_logloss: 0.529976
# [79]	training's binary_logloss: 0.528696
# [80]	training's binary_logloss: 0.527425
# [81]	training's binary_logloss: 0.526266
# [82]	training's binary_logloss: 0.525749
# [83]	training's binary_logloss: 0.52451
# [84]	training's binary_logloss: 0.523313
# [85]	training's binary_logloss: 0.522183
# [86]	training's binary_logloss: 0.521006
# [87]	training's binary_logloss: 0.519845
# [88]	training's binary_logloss: 0.51869
# [89]	training's binary_logloss: 0.517547
# [90]	training's binary_logloss: 0.51642
# [91]	training's binary_logloss: 0.515406
# [92]	training's binary_logloss: 0.514311
# [93]	training's binary_logloss: 0.513232
# [94]	training's binary_logloss: 0.512753
# [95]	training's binary_logloss: 0.511704
# [96]	training's binary_logloss: 0.511203
# [97]	training's binary_logloss: 0.510323
# [98]	training's binary_logloss: 0.509305
# [99]	training's binary_logloss: 0.508377
# [100]	training's binary_logloss: 0.507365
# [101]	training's binary_logloss: 0.50689
# [102]	training's binary_logloss: 0.506453
# [103]	training's binary_logloss: 0.505465
# [104]	training's binary_logloss: 0.504502
# [105]	training's binary_logloss: 0.503558
# [106]	training's binary_logloss: 0.502604
# [107]	training's binary_logloss: 0.502167
# [108]	training's binary_logloss: 0.501233
# [109]	training's binary_logloss: 0.500311
# [110]	training's binary_logloss: 0.499498
# [111]	training's binary_logloss: 0.49908
# [112]	training's binary_logloss: 0.498196
# [113]	training's binary_logloss: 0.4974
# [114]	training's binary_logloss: 0.496613
# [115]	training's binary_logloss: 0.495762
# [116]	training's binary_logloss: 0.495431
# [117]	training's binary_logloss: 0.494655
# [118]	training's binary_logloss: 0.493811
# [119]	training's binary_logloss: 0.492997
# [120]	training's binary_logloss: 0.492268
# [121]	training's binary_logloss: 0.491602
# [122]	training's binary_logloss: 0.491227
# [123]	training's binary_logloss: 0.490499
# [124]	training's binary_logloss: 0.49022
# [125]	training's binary_logloss: 0.489472
# [126]	training's binary_logloss: 0.488764
# [127]	training's binary_logloss: 0.487998
# [128]	training's binary_logloss: 0.487321
# [129]	training's binary_logloss: 0.486583
# [130]	training's binary_logloss: 0.48632
# [131]	training's binary_logloss: 0.485596
# [132]	training's binary_logloss: 0.484901
# [133]	training's binary_logloss: 0.484247
# [134]	training's binary_logloss: 0.48357
# [135]	training's binary_logloss: 0.483274
# [136]	training's binary_logloss: 0.482962
# [137]	training's binary_logloss: 0.482263
# [138]	training's binary_logloss: 0.481999
# [139]	training's binary_logloss: 0.481344
# [140]	training's binary_logloss: 0.480659
# [141]	training's binary_logloss: 0.480349
# [142]	training's binary_logloss: 0.47976
# [143]	training's binary_logloss: 0.479109
# [144]	training's binary_logloss: 0.478467
# [145]	training's binary_logloss: 0.478168
# [146]	training's binary_logloss: 0.47787
# [147]	training's binary_logloss: 0.477243
# [148]	training's binary_logloss: 0.476959
# [149]	training's binary_logloss: 0.476726
# [150]	training's binary_logloss: 0.476176
# [151]	training's binary_logloss: 0.475902
# [152]	training's binary_logloss: 0.475361
# [153]	training's binary_logloss: 0.475078
# [154]	training's binary_logloss: 0.474852
# [155]	training's binary_logloss: 0.474236
# [156]	training's binary_logloss: 0.473658
# [157]	training's binary_logloss: 0.473061
# [158]	training's binary_logloss: 0.472485
# [159]	training's binary_logloss: 0.471903
# [160]	training's binary_logloss: 0.47167
# [161]	training's binary_logloss: 0.471097
# [162]	training's binary_logloss: 0.470543
# [163]	training's binary_logloss: 0.470011
# [164]	training's binary_logloss: 0.469455
# [165]	training's binary_logloss: 0.46892
# [166]	training's binary_logloss: 0.468404
# [167]	training's binary_logloss: 0.467905
# [168]	training's binary_logloss: 0.467389
# [169]	training's binary_logloss: 0.466892
# [170]	training's binary_logloss: 0.466413
# [171]	training's binary_logloss: 0.46617
# [172]	training's binary_logloss: 0.46594
# [173]	training's binary_logloss: 0.465747
# [174]	training's binary_logloss: 0.465543
# [175]	training's binary_logloss: 0.465107
# [176]	training's binary_logloss: 0.464678
# [177]	training's binary_logloss: 0.464423
# [178]	training's binary_logloss: 0.464
# [179]	training's binary_logloss: 0.463802
# [180]	training's binary_logloss: 0.463326
# [181]	training's binary_logloss: 0.463135
# [182]	training's binary_logloss: 0.462686
# [183]	training's binary_logloss: 0.462511
# [184]	training's binary_logloss: 0.462339
# [185]	training's binary_logloss: 0.461879
# [186]	training's binary_logloss: 0.461432
# [187]	training's binary_logloss: 0.460982
# [188]	training's binary_logloss: 0.460538
# [189]	training's binary_logloss: 0.460373
# [190]	training's binary_logloss: 0.459981
# [191]	training's binary_logloss: 0.459564
# [192]	training's binary_logloss: 0.459135
# [193]	training's binary_logloss: 0.458732
# [194]	training's binary_logloss: 0.458303
# [195]	training's binary_logloss: 0.458078
# [196]	training's binary_logloss: 0.457718
# [197]	training's binary_logloss: 0.457363
# [198]	training's binary_logloss: 0.45717
# [199]	training's binary_logloss: 0.456765
# [200]	training's binary_logloss: 0.456436
# D:\Anaconda\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# D:\Anaconda\lib\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')

# %%
sub = pd.DataFrame(test['PassengerId'])
sub['Survived'] = y_pred
sub.to_csv('Submission_benchmark.csv',index=False)

# %% [markdown]
# ### Score: 0.77033

# %% [markdown]
# ### Try Rf

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

rf = RandomForestClassifier()

param_grid_rf = {'n_estimators': np.arange(50, 500, 50),
                'max_depth': np.arange(4, 14, 2),
                'min_samples_split': np.arange(2, 20),
                'max_features':[0.6, 0.7, 0.8, 0.9]}

rf_rand = RandomizedSearchCV(rf, param_distributions=param_grid_rf, n_jobs=3, cv=5)
rf_rand.fit(X_train, y_train)
y_pred = rf_rand.predict(test)

sub = pd.DataFrame(test['PassengerId'])
sub['Survived'] = y_pred
sub.to_csv('Submission_benchmark_rf.csv',index=False)
